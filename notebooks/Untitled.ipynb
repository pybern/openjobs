# %%
from elasticsearch import Elasticsearch
es = Elasticsearch('http://localhost:9200')

# %%
es.search(index = 'jobs', doc_type='jobs', body = {'query':{'match':{'text':'petaling jaya'}}})
# Out:
# {'took': 1,
#  'timed_out': False,
#  '_shards': {'total': 5, 'successful': 5, 'skipped': 0, 'failed': 0},
#  'hits': {'total': 0, 'max_score': None, 'hits': []}}

# %%
from datetime import datetime
from itertools import zip_longest
import json
from urllib.parse import urljoin
import os
from os.path import join
import re
#from multiprocessing import Pool
#from subprocess import Popen, PIPE


import requests
from requests_html import HTMLSession
from bs4 import BeautifulSoup


def kpmg():

    
    kpmg_list = []
    kpmg_pre_url = 'https://www.kpmg.com.my/KARSFR/'
    kpmg_url = urljoin(kpmg_pre_url,'candViewAd.aspx')
    
    kpmg_job_url = 'https://www.kpmg.com.my/KARSFR/candAdDetails.aspx?AdvertID={}'

    try:
        r = requests.get(kpmg_url)
    except requests.exceptions.RequestException as e:
        print("An exception occured while connecting to {}".format(kpmg_url))
        print(e)

    soup = BeautifulSoup(r.content, 'lxml')
    
    
    for r in soup.find('table', id = 'MyGrid').find_all('tr')[1:]:
        content = r.find_all('font')
            
            #dates = [i.next_sibling for i in content[0].find_all('b')]
            #ref = content[4].text
        location = content[5].text.strip()
        department = content[6].text.strip()
        title = content[2].find('b').text.strip()
        link = kpmg_job_url.format(content[2].find('a')['onclick'].split("'")[1].split('=')[-1].strip())

        kpmg_list.append(('KPMG',title, location, department, link, datetime.utcnow()))
    
    return kpmg_list

# %%
k = kpmg()

# %%
k
# Out:
# [('KPMG',
#   'Tax Consulting Assistant - Corporate Tax',
#   'Petaling Jaya',
#   'Corporate Tax',
#   'https://www.kpmg.com.my/KARSFR/candAdDetails.aspx?AdvertID=3333',
#   datetime.datetime(2018, 9, 4, 13, 18, 11, 22996)),
#  ('KPMG',
#   'Tax Consultant - Corporate Tax',
#   'Petaling Jaya',
#   'Corporate Tax',
#   'https://www.kpmg.com.my/KARSFR/candAdDetails.aspx?AdvertID=3247',
#   datetime.datetime(2018, 9, 4, 13, 18, 11, 22996)),
#  ('KPMG',
#   'IT Consultant – Assistant Manager (Workday)',
#   'Petaling Jaya',
#   'Information Technology Enabled Transformation',
#   'https://www.kpmg.com.my/KARSFR/candAdDetails.aspx?AdvertID=3384',
#   datetime.datetime(2018, 9, 4, 13, 18, 11, 22996)),
#  ('KPMG',
#   'Senior PHP Developer',
#   'Petaling Jaya',
#   'Emerging Tech Risk & Cyber (Security)',
#   'https://www.kpmg.com.my/KARSFR/candAdDetails.aspx?AdvertID=1968',
#   datetime.datetime(2018, 9, 4, 13, 18, 11, 22996)),
#  ('KPMG',
#   'Senior Associate/Assisant Manager – Enterprise Risk Management (Transaction Services)',
#   'Petaling Jaya',
#   'Transaction Services',
#   'https://www.kpmg.com.my/KARSFR/candAdDetails.aspx?AdvertID=3366',
#   datetime.datetime(2018, 9, 4, 13, 18, 11, 22996)),
#  ('KPMG',
#   'Project Manager  – (ITET)  Enterprise Architecture',
#   'Petaling Jaya',
#   'Information Technology Enabled Transformation',
#   'https://www.kpmg.com.my/KARSFR/candAdDetails.aspx?AdvertID=3267',
#   datetime.datetime(2018, 9, 4, 13, 18, 11, 22996)),
#  ('KPMG',
#   'Project Manager  – (ITET) IT Strategy',
#   'Petaling Jaya',
#   'Information Technology Enabled Transformation',
#   'https://www.kpmg.com.my/KARSFR/candAdDetails.aspx?AdvertID=3268',
#   datetime.datetime(2018, 9, 4, 13, 18, 11, 23999)),
#  ('KPMG',
#   'Senior Associate/Assistant Manager - IT Infrastructure (ITA)',
#   'Petaling Jaya',
#   'Information Technology Enabled Transformation',
#   'https://www.kpmg.com.my/KARSFR/candAdDetails.aspx?AdvertID=1340',
#   datetime.datetime(2018, 9, 4, 13, 18, 11, 23999)),
#  ('KPMG',
#   'Global and Domestic Compliance Management Services Compliance Consultant',
#   'Petaling Jaya',
#   'Global Compliance Management Services',
#   'https://www.kpmg.com.my/KARSFR/candAdDetails.aspx?AdvertID=3364',
#   datetime.datetime(2018, 9, 4, 13, 18, 11, 23999)),
#  ('KPMG',
#   'Senior Associate - Forensic Services',
#   'Petaling Jaya',
#   'Forensic Services',
#   'https://www.kpmg.com.my/KARSFR/candAdDetails.aspx?AdvertID=3367',
#   datetime.datetime(2018, 9, 4, 13, 18, 11, 23999)),
#  ('KPMG',
#   'Assistant Manager/Manager (FRS) - Forensic Technology & Data Analytics',
#   'Petaling Jaya',
#   'Forensic Services',
#   'https://www.kpmg.com.my/KARSFR/candAdDetails.aspx?AdvertID=3273',
#   datetime.datetime(2018, 9, 4, 13, 18, 11, 23999)),
#  ('KPMG',
#   'Associate - Corporate Restructuring',
#   'Petaling Jaya',
#   'Corporate Restructuring',
#   'https://www.kpmg.com.my/KARSFR/candAdDetails.aspx?AdvertID=3339',
#   datetime.datetime(2018, 9, 4, 13, 18, 11, 25001)),
#  ('KPMG',
#   'Manager - Financial Management',
#   'Petaling Jaya',
#   'Financial Management (Management Consulting)',
#   'https://www.kpmg.com.my/KARSFR/candAdDetails.aspx?AdvertID=3394',
#   datetime.datetime(2018, 9, 4, 13, 18, 11, 25001)),
#  ('KPMG',
#   'Manager - Corporate Finance (Valuation, M&A and Infrastructure & Projects Advisory practices)',
#   'Petaling Jaya',
#   'Corporate Finance',
#   'https://www.kpmg.com.my/KARSFR/candAdDetails.aspx?AdvertID=3313',
#   datetime.datetime(2018, 9, 4, 13, 18, 11, 25001)),
#  ('KPMG',
#   'Senior Associate/Assistant Manager - Corporate Finance (Valuation, M&A, and Infrastructure & Projects Advisory practices)',
#   'Petaling Jaya',
#   'Corporate Finance',
#   'https://www.kpmg.com.my/KARSFR/candAdDetails.aspx?AdvertID=3314',
#   datetime.datetime(2018, 9, 4, 13, 18, 11, 25001)),
#  ('KPMG',
#   'IT Consultant – Assistant Manager (PMO)',
#   'Petaling Jaya',
#   'Emerging Tech Risk & Cyber (Security)',
#   'https://www.kpmg.com.my/KARSFR/candAdDetails.aspx?AdvertID=3377',
#   datetime.datetime(2018, 9, 4, 13, 18, 11, 26004)),
#  ('KPMG',
#   'Senior Associate / Assistant Manager – ITA – Emerging Tech Risk and Cyber (Cyber Security Consultant)',
#   'Petaling Jaya',
#   'Emerging Tech Risk & Cyber (Security)',
#   'https://www.kpmg.com.my/KARSFR/candAdDetails.aspx?AdvertID=3378',
#   datetime.datetime(2018, 9, 4, 13, 18, 11, 26004)),
#  ('KPMG',
#   'Associate / Senior Associate – Cyber Defense/Penetration Testing',
#   'Petaling Jaya',
#   'Emerging Tech Risk & Cyber (Security)',
#   'https://www.kpmg.com.my/KARSFR/candAdDetails.aspx?AdvertID=1441',
#   datetime.datetime(2018, 9, 4, 13, 18, 11, 26004)),
#  ('KPMG',
#   'Executive/Senior Executive (Allocation Specialist) - Emerging Tech Risk & Cyber',
#   'Petaling Jaya',
#   'Emerging Tech Risk & Cyber (Security)',
#   'https://www.kpmg.com.my/KARSFR/candAdDetails.aspx?AdvertID=3359',
#   datetime.datetime(2018, 9, 4, 13, 18, 11, 26004)),
#  ('KPMG',
#   'Internship - Global Mobility Services',
#   'Petaling Jaya',
#   'Global Mobility Services',
#   'https://www.kpmg.com.my/KARSFR/candAdDetails.aspx?AdvertID=3404',
#   datetime.datetime(2018, 9, 4, 13, 18, 11, 27007)),
#  ('KPMG',
#   'Senior Manager/ Manager - Department of Professional Practice (Risk Management)',
#   'Petaling Jaya',
#   'Department of Professional Practice',
#   'https://www.kpmg.com.my/KARSFR/candAdDetails.aspx?AdvertID=3403',
#   datetime.datetime(2018, 9, 4, 13, 18, 11, 27007)),
#  ('KPMG',
#   'Manager - People & Change',
#   'Petaling Jaya',
#   'People and Change (Management Consulting)',
#   'https://www.kpmg.com.my/KARSFR/candAdDetails.aspx?AdvertID=1999',
#   datetime.datetime(2018, 9, 4, 13, 18, 11, 27007)),
#  ('KPMG',
#   'Manager - Department of Professional Practice',
#   'Petaling Jaya',
#   'Department of Professional Practice',
#   'https://www.kpmg.com.my/KARSFR/candAdDetails.aspx?AdvertID=1754',
#   datetime.datetime(2018, 9, 4, 13, 18, 11, 27007)),
#  ('KPMG',
#   'Immigration Consulting Assistant – Global Mobility Services',
#   'Petaling Jaya',
#   'Global Mobility Services',
#   'https://www.kpmg.com.my/KARSFR/candAdDetails.aspx?AdvertID=3401',
#   datetime.datetime(2018, 9, 4, 13, 18, 11, 27007)),
#  ('KPMG',
#   'Robotic Process Automation Developer - Information Technology Enabled Transformation',
#   'Petaling Jaya',
#   'Information Technology Enabled Transformation',
#   'https://www.kpmg.com.my/KARSFR/candAdDetails.aspx?AdvertID=3133',
#   datetime.datetime(2018, 9, 4, 13, 18, 11, 27007)),
#  ('KPMG',
#   'Senior Associate/Assistant Manager – Blockchain Innovator',
#   'Petaling Jaya',
#   'Information Technology Enabled Transformation',
#   'https://www.kpmg.com.my/KARSFR/candAdDetails.aspx?AdvertID=3196',
#   datetime.datetime(2018, 9, 4, 13, 18, 11, 28009)),
#  ('KPMG',
#   'Internship - Corporate Tax',
#   'Johor Bahru',
#   'Corporate Tax',
#   'https://www.kpmg.com.my/KARSFR/candAdDetails.aspx?AdvertID=3400',
#   datetime.datetime(2018, 9, 4, 13, 18, 11, 28009)),
#  ('KPMG',
#   'Tax Consulting Assistants',
#   'Johor Bahru',
#   'Corporate Tax',
#   'https://www.kpmg.com.my/KARSFR/candAdDetails.aspx?AdvertID=3399',
#   datetime.datetime(2018, 9, 4, 13, 18, 11, 28009)),
#  ('KPMG',
#   'Internship - Audit Assurance',
#   'Johor Bahru',
#   'Audit Assurances',
#   'https://www.kpmg.com.my/KARSFR/candAdDetails.aspx?AdvertID=3397',
#   datetime.datetime(2018, 9, 4, 13, 18, 11, 28009)),
#  ('KPMG',
#   'Audit Associate',
#   'Johor Bahru',
#   'Audit Assurances',
#   'https://www.kpmg.com.my/KARSFR/candAdDetails.aspx?AdvertID=3398',
#   datetime.datetime(2018, 9, 4, 13, 18, 11, 28009)),
#  ('KPMG',
#   'Senior Associate/Assistant Manager - SAP Financial Consultant',
#   'Petaling Jaya',
#   'Information Technology Enabled Transformation',
#   'https://www.kpmg.com.my/KARSFR/candAdDetails.aspx?AdvertID=3395',
#   datetime.datetime(2018, 9, 4, 13, 18, 11, 29012)),
#  ('KPMG',
#   'Manager - ETRC - Business Development',
#   'Petaling Jaya',
#   'Emerging Tech Risk & Cyber (Security)',
#   'https://www.kpmg.com.my/KARSFR/candAdDetails.aspx?AdvertID=3350',
#   datetime.datetime(2018, 9, 4, 13, 18, 11, 29012)),
#  ('KPMG',
#   'Senior Associate/Assistant Manager/Manager (IARCS) - IT Internal Audit',
#   'Petaling Jaya',
#   'Internal Audit, Risk and Compliance Services',
#   'https://www.kpmg.com.my/KARSFR/candAdDetails.aspx?AdvertID=3285',
#   datetime.datetime(2018, 9, 4, 13, 18, 11, 29012)),
#  ('KPMG',
#   'Assistant Manager/Manager (Governance)',
#   'Petaling Jaya',
#   'Governance and Sustainability',
#   'https://www.kpmg.com.my/KARSFR/candAdDetails.aspx?AdvertID=3355',
#   datetime.datetime(2018, 9, 4, 13, 18, 11, 29012)),
#  ('KPMG',
#   'Audit Associate',
#   'Kota Kinabalu',
#   'Audit Assurances',
#   'https://www.kpmg.com.my/KARSFR/candAdDetails.aspx?AdvertID=3390',
#   datetime.datetime(2018, 9, 4, 13, 18, 11, 30015)),
#  ('KPMG',
#   'Internship - Audit Assurance',
#   'Petaling Jaya',
#   'Audit Assurances',
#   'https://www.kpmg.com.my/KARSFR/candAdDetails.aspx?AdvertID=3387',
#   datetime.datetime(2018, 9, 4, 13, 18, 11, 30015)),
#  ('KPMG',
#   'Internship - Data Analyst',
#   'Petaling Jaya',
#   'Data & Analytics',
#   'https://www.kpmg.com.my/KARSFR/candAdDetails.aspx?AdvertID=3365',
#   datetime.datetime(2018, 9, 4, 13, 18, 11, 30015)),
#  ('KPMG',
#   'Internship - Audit Centralization Team',
#   'Petaling Jaya',
#   'Audit Centralization Team (Audit - Admin)',
#   'https://www.kpmg.com.my/KARSFR/candAdDetails.aspx?AdvertID=3266',
#   datetime.datetime(2018, 9, 4, 13, 18, 11, 30015)),
#  ('KPMG',
#   'Associate/Senior Associate ERP Advisory Consultant',
#   'Petaling Jaya',
#   'Information Technology Enabled Transformation',
#   'https://www.kpmg.com.my/KARSFR/candAdDetails.aspx?AdvertID=3383',
#   datetime.datetime(2018, 9, 4, 13, 18, 11, 30015)),
#  ('KPMG',
#   'KBS Learning & Development - Assistant (Student Affairs)',
#   'Petaling Jaya',
#   'KPMG Business School (L&D)',
#   'https://www.kpmg.com.my/KARSFR/candAdDetails.aspx?AdvertID=3382',
#   datetime.datetime(2018, 9, 4, 13, 18, 11, 30015)),
#  ('KPMG',
#   'Audit Assistant',
#   'Petaling Jaya',
#   'Audit Assurances',
#   'https://www.kpmg.com.my/KARSFR/candAdDetails.aspx?AdvertID=3381',
#   datetime.datetime(2018, 9, 4, 13, 18, 11, 31017)),
#  ('KPMG',
#   'Tax Consultant / Senior Tax Consultant / Assistant Tax Manager – Department of Professional Practice (DPP Tax)',
#   'Petaling Jaya',
#   'Corporate Tax',
#   'https://www.kpmg.com.my/KARSFR/candAdDetails.aspx?AdvertID=3380',
#   datetime.datetime(2018, 9, 4, 13, 18, 11, 31017)),
#  ('KPMG',
#   'Internship - People & Change (Management Consulting)',
#   'Petaling Jaya',
#   'People and Change (Management Consulting)',
#   'https://www.kpmg.com.my/KARSFR/candAdDetails.aspx?AdvertID=3371',
#   datetime.datetime(2018, 9, 4, 13, 18, 11, 31017)),
#  ('KPMG',
#   'Internship - Internal Audit and Risk Consulting Services (Risk Consulting)',
#   'Petaling Jaya',
#   'Internal Audit, Risk and Compliance Services',
#   'https://www.kpmg.com.my/KARSFR/candAdDetails.aspx?AdvertID=3370',
#   datetime.datetime(2018, 9, 4, 13, 18, 11, 31017)),
#  ('KPMG',
#   'Internship - Accounting Advisory Services (Risk Consulting)',
#   'Petaling Jaya',
#   'Accounting Advisory Services',
#   'https://www.kpmg.com.my/KARSFR/candAdDetails.aspx?AdvertID=3369',
#   datetime.datetime(2018, 9, 4, 13, 18, 11, 31017)),
#  ('KPMG',
#   'Internship - Governance & Sustainability (Risk Consulting)',
#   'Petaling Jaya',
#   'Governance and Sustainability',
#   'https://www.kpmg.com.my/KARSFR/candAdDetails.aspx?AdvertID=3368',
#   datetime.datetime(2018, 9, 4, 13, 18, 11, 31017)),
#  ('KPMG',
#   'Internship - Financial Risk Management (Risk Consulting)',
#   'Petaling Jaya',
#   'Financial Risk Management',
#   'https://www.kpmg.com.my/KARSFR/candAdDetails.aspx?AdvertID=3300',
#   datetime.datetime(2018, 9, 4, 13, 18, 11, 32020)),
#  ('KPMG',
#   'Internship - Emerging Tech Risk & Cyber (Security)',
#   'Petaling Jaya',
#   'Emerging Tech Risk & Cyber (Security)',
#   'https://www.kpmg.com.my/KARSFR/candAdDetails.aspx?AdvertID=3361',
#   datetime.datetime(2018, 9, 4, 13, 18, 11, 32020)),
#  ('KPMG',
#   'Internship - Information Technology Enabled Transformation (IT Advisory)',
#   'Petaling Jaya',
#   'Information Technology Enabled Transformation',
#   'https://www.kpmg.com.my/KARSFR/candAdDetails.aspx?AdvertID=3303',
#   datetime.datetime(2018, 9, 4, 13, 18, 11, 32020)),
#  ('KPMG',
#   'Internship - Information Technology Services (ITS)',
#   'Petaling Jaya',
#   'Information Technology Services',
#   'https://www.kpmg.com.my/KARSFR/candAdDetails.aspx?AdvertID=3302',
#   datetime.datetime(2018, 9, 4, 13, 18, 11, 32020)),
#  ('KPMG',
#   'Internship - KPMG Business School (Learning & Development)',
#   'Petaling Jaya',
#   'KPMG Business School (L&D)',
#   'https://www.kpmg.com.my/KARSFR/candAdDetails.aspx?AdvertID=3299',
#   datetime.datetime(2018, 9, 4, 13, 18, 11, 32020)),
#  ('KPMG',
#   'Internship - People, Performance & Culture (Human Resource)',
#   'Petaling Jaya',
#   'People, Performance, and Culture (HR)',
#   'https://www.kpmg.com.my/KARSFR/candAdDetails.aspx?AdvertID=3307',
#   datetime.datetime(2018, 9, 4, 13, 18, 11, 32020)),
#  ('KPMG',
#   'Senior Associate – Information Risk Management (“IRM”) Specialist',
#   'Petaling Jaya',
#   'Information Risk Management (IT Audit)',
#   'https://www.kpmg.com.my/KARSFR/candAdDetails.aspx?AdvertID=3069',
#   datetime.datetime(2018, 9, 4, 13, 18, 11, 32020)),
#  ('KPMG',
#   'Data Analyst (Experienced)',
#   'Petaling Jaya',
#   'Data & Analytics',
#   'https://www.kpmg.com.my/KARSFR/candAdDetails.aspx?AdvertID=3363',
#   datetime.datetime(2018, 9, 4, 13, 18, 11, 33022)),
#  ('KPMG',
#   'Internship - Audit Centralization Team',
#   'Petaling Jaya',
#   'Audit Centralization Team (Audit - Admin)',
#   'https://www.kpmg.com.my/KARSFR/candAdDetails.aspx?AdvertID=3290',
#   datetime.datetime(2018, 9, 4, 13, 18, 11, 33022)),
#  ('KPMG',
#   'ITS - Officer (Helpdesk Support Officer)',
#   'Penang',
#   'Information Technology Services',
#   'https://www.kpmg.com.my/KARSFR/candAdDetails.aspx?AdvertID=1793',
#   datetime.datetime(2018, 9, 4, 13, 18, 11, 33022)),
#  ('KPMG',
#   'Tax Manager - Department of Professional Practice (DPP Tax)',
#   'Petaling Jaya',
#   'Corporate Tax',
#   'https://www.kpmg.com.my/KARSFR/candAdDetails.aspx?AdvertID=3256',
#   datetime.datetime(2018, 9, 4, 13, 18, 11, 33022)),
#  ('KPMG',
#   'Administration Assistant/Officer',
#   'Petaling Jaya',
#   'Audit Centralization Team (Audit - Admin)',
#   'https://www.kpmg.com.my/KARSFR/candAdDetails.aspx?AdvertID=3351',
#   datetime.datetime(2018, 9, 4, 13, 18, 11, 33022)),
#  ('KPMG',
#   'ITS - Senior Executive / Assistant Manager for System Servers / Network Support',
#   'Petaling Jaya',
#   'Information Technology Services',
#   'https://www.kpmg.com.my/KARSFR/candAdDetails.aspx?AdvertID=1695',
#   datetime.datetime(2018, 9, 4, 13, 18, 11, 33022)),
#  ('KPMG',
#   'ITS - Executive / Senior Executive for Application / Development and Support',
#   'Petaling Jaya',
#   'Information Technology Services',
#   'https://www.kpmg.com.my/KARSFR/candAdDetails.aspx?AdvertID=1741',
#   datetime.datetime(2018, 9, 4, 13, 18, 11, 33022)),
#  ('KPMG',
#   'Associate – Information Risk Management (“IRM”) Specialist',
#   'Petaling Jaya',
#   'Information Risk Management (IT Audit)',
#   'https://www.kpmg.com.my/KARSFR/candAdDetails.aspx?AdvertID=3068',
#   datetime.datetime(2018, 9, 4, 13, 18, 11, 33022)),
#  ('KPMG',
#   'Audit Associate',
#   'Petaling Jaya',
#   'Audit Assurances',
#   'https://www.kpmg.com.my/KARSFR/candAdDetails.aspx?AdvertID=3216',
#   datetime.datetime(2018, 9, 4, 13, 18, 11, 33022)),
#  ('KPMG',
#   'Audit Senior Associate',
#   'Petaling Jaya',
#   'Audit Assurances',
#   'https://www.kpmg.com.my/KARSFR/candAdDetails.aspx?AdvertID=1027',
#   datetime.datetime(2018, 9, 4, 13, 18, 11, 33022)),
#  ('KPMG',
#   'Internship - Internal Audit, Risk & Compliance Services',
#   'Penang',
#   'Internal Audit, Risk & Compliance Services(Penang)',
#   'https://www.kpmg.com.my/KARSFR/candAdDetails.aspx?AdvertID=1709',
#   datetime.datetime(2018, 9, 4, 13, 18, 11, 33022)),
#  ('KPMG',
#   'Associate - Internal Audit, Risk & Compliance Services',
#   'Penang',
#   'Internal Audit, Risk & Compliance Services(Penang)',
#   'https://www.kpmg.com.my/KARSFR/candAdDetails.aspx?AdvertID=1726',
#   datetime.datetime(2018, 9, 4, 13, 18, 11, 34025)),
#  ('KPMG',
#   'Senior Associate - Internal Audit, Risk and Compliance Services',
#   'Penang',
#   'Internal Audit, Risk & Compliance Services(Penang)',
#   'https://www.kpmg.com.my/KARSFR/candAdDetails.aspx?AdvertID=1725',
#   datetime.datetime(2018, 9, 4, 13, 18, 11, 34025)),
#  ('KPMG',
#   'Assistant Manager - Internal Audit, Risk and Compliance Services',
#   'Penang',
#   'Internal Audit, Risk & Compliance Services(Penang)',
#   'https://www.kpmg.com.my/KARSFR/candAdDetails.aspx?AdvertID=1760',
#   datetime.datetime(2018, 9, 4, 13, 18, 11, 34025)),
#  ('KPMG',
#   'Manager - Internal Audit, Risk and Compliance Services',
#   'Penang',
#   'Internal Audit, Risk & Compliance Services(Penang)',
#   'https://www.kpmg.com.my/KARSFR/candAdDetails.aspx?AdvertID=1759',
#   datetime.datetime(2018, 9, 4, 13, 18, 11, 34025))]
